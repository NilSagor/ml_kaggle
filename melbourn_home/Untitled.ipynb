# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
home_data = pd.read_csv("melb_data.csv")

# %%
home_data.shape
# Out:
# (13580, 21)

# %%
home_data.sample(n=5, random_state = 1)
# Out:
#              Suburb              Address  Rooms Type      Price Method  \
# 321      Ascot Vale         7 Angler Pde      4    h  1640000.0      S
# 4003      Melbourne  702/108 Flinders St      2    u   675000.0     VB
# 13348  Balwyn North          1 Hosken St      5    h  2800000.0      S
# 2697      Footscray      6/63 Everard St      2    u   615000.0      S
# 12600   Sandringham       50 Bamfield St      4    h  2700000.0      S
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# 321            Raine  16/04/2016       5.9    3032.0       4.0       3.0  2.0
# 4003             Kay  24/09/2016       2.8    3000.0       2.0       2.0  1.0
# 13348       Marshall  26/08/2017       9.7    3104.0       5.0       2.0  2.0
# 2697         Sweeney  16/04/2016       6.4    3011.0       2.0       1.0  3.0
# 12600  hockingstuart   9/09/2017      15.2    3191.0       4.0       2.0  1.0
#
#        Landsize  BuildingArea  YearBuilt    CouncilArea  Lattitude  \
# ...

# %%
# select target variables
y = home_data.Price

# %%
# select features
X = home_data.drop("Price", axis = 1)

# %%
X.head()
# Out:
#        Suburb           Address  Rooms Type Method SellerG       Date  \
# 0  Abbotsford      85 Turner St      2    h      S  Biggin  3/12/2016
# 1  Abbotsford   25 Bloomburg St      2    h      S  Biggin  4/02/2016
# 2  Abbotsford      5 Charles St      3    h     SP  Biggin  4/03/2017
# 3  Abbotsford  40 Federation La      3    h     PI  Biggin  4/03/2017
# 4  Abbotsford       55a Park St      4    h     VB  Nelson  4/06/2016
#
#    Distance  Postcode  Bedroom2  Bathroom  Car  Landsize  BuildingArea  \
# 0       2.5    3067.0       2.0       1.0  1.0     202.0           NaN
# 1       2.5    3067.0       2.0       1.0  0.0     156.0          79.0
# 2       2.5    3067.0       3.0       2.0  0.0     134.0         150.0
# 3       2.5    3067.0       3.0       2.0  1.0      94.0           NaN
# 4       2.5    3067.0       3.0       1.0  2.0     120.0         142.0
#
#    YearBuilt CouncilArea  Lattitude  Longtitude             Regionname  \
# ...

# %%
# split the data in to training and validation for both target and features

from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = train_test_split(X, y, train_size = 0.80, test_size = 0.20, random_state = 5)
