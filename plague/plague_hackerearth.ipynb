# %%
#import libraries
import pandas as pd
pd.set_option("display.max_column", None)
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from pandas import Series
import warnings
warnings.filterwarnings("ignore")

# %%
#load data
plague_train = pd.read_csv("train.csv", parse_dates = ['DateTime'])
plague_test = pd.read_csv("test.csv", parse_dates = ['DateTime'])

# %%
plague_train.info()
plague_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 37 columns):
# ID              40000 non-null object
# DateTime        40000 non-null datetime64[ns]
# TempOut         40000 non-null float64
# HiTemp          40000 non-null float64
# LowTemp         40000 non-null float64
# OutHum          40000 non-null int64
# DewPt           40000 non-null float64
# WindSpeed       40000 non-null int64
# WindDir         40000 non-null object
# WindRun         40000 non-null float64
# HiSpeed         40000 non-null int64
# HiDir           40000 non-null object
# WindChill       40000 non-null float64
# HeatIndex       40000 non-null float64
# THWIndex        40000 non-null float64
# Bar             40000 non-null float64
# Rain            40000 non-null float64
# RainRate        40000 non-null float64
# HeatDD          40000 non-null float64
# CoolDD          40000 non-null float64
# InTemp          40000 non-null float64
# ...

# %%
plague_train.head()
# Out:
#         ID            DateTime  TempOut  HiTemp  LowTemp  OutHum  DewPt  \
# 0  PR00001 2040-07-12 00:15:00     53.5    53.6     53.5      85   49.1
# 1  PR00002 2040-07-12 00:30:00     53.5    53.5     53.4      85   49.1
# 2  PR00003 2040-07-12 00:45:00     53.3    53.5     53.2      85   48.9
# 3  PR00004 2040-07-12 01:00:00     53.1    53.3     53.0      86   49.0
# 4  PR00005 2040-07-12 01:15:00     52.9    53.1     52.9      86   48.8
#
#    WindSpeed WindDir  WindRun  HiSpeed HiDir  WindChill  HeatIndex  THWIndex  \
# 0          2     SSE      0.5        9    SE       53.5       53.4      53.4
# 1          2     SSE      0.5        7   SSE       53.5       53.4      53.4
# 2          2     SSE      0.5        7   SSE       53.3       53.2      53.2
# 3          2       S      0.5        5     S       53.1       53.0      53.0
# 4          2       S      0.5        6    SW       52.9       52.9      52.9
#
# ...

# %%
# copy data while we have changed data, we will not losing data
plague_train_original = plague_train.copy()
plague_test_original = plague_test.copy()

# %%
# datetime object need to convert datetime format
#plague_train['DateTime'] = pd.to_datetime(plague_train.DateTime, format = "%m-%d-%Y %H:%M")
#plague_test['DateTime'] = pd.to_datetime(plague_test.DateTime, format = "%m-%d-%Y %H:%M")
#plague_train_original['DateTime'] = pd.to_datetime(plague_train_original.DateTime, format = "%m-%d-%Y %H:%M")
#plague_test_original['DateTime'] = pd.to_datetime(plague_test_original.DateTime, format = "%m-%d-%Y %H:%M")
plague_train.describe()
# Out:
#             TempOut        HiTemp       LowTemp        OutHum         DewPt  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean      58.508625     58.975230     58.056785     72.915750     48.156872
# std       12.119640     12.323427     11.916335     20.873482      7.895771
# min       29.300000     29.500000     29.300000      4.000000      1.200000
# 25%       51.100000     51.300000     50.800000     58.000000     43.600000
# 50%       56.400000     56.800000     56.100000     79.000000     49.700000
# 75%       65.300000     66.000000     64.700000     91.000000     53.900000
# max      110.300000    111.000000    108.600000     98.000000     66.900000
#
#           WindSpeed       WindRun       HiSpeed     WindChill     HeatIndex  \
# count  40000.000000  40000.000000  40000.000000  40000.000000  40000.000000
# mean       2.348650      0.587163      6.028675     58.373335     58.139202
# ...

# %%
plague_train.info().dtype(include = "object")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 37 columns):
# ID              40000 non-null object
# DateTime        40000 non-null datetime64[ns]
# TempOut         40000 non-null float64
# HiTemp          40000 non-null float64
# LowTemp         40000 non-null float64
# OutHum          40000 non-null int64
# DewPt           40000 non-null float64
# WindSpeed       40000 non-null int64
# WindDir         40000 non-null object
# WindRun         40000 non-null float64
# HiSpeed         40000 non-null int64
# HiDir           40000 non-null object
# WindChill       40000 non-null float64
# HeatIndex       40000 non-null float64
# THWIndex        40000 non-null float64
# Bar             40000 non-null float64
# Rain            40000 non-null float64
# RainRate        40000 non-null float64
# HeatDD          40000 non-null float64
# CoolDD          40000 non-null float64
# InTemp          40000 non-null float64
# ...

# %%
plague_train.index = plague_train['DateTime']
df = plague_train['ID', axis = 1]
ts = df[]
